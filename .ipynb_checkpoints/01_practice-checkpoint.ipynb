# %%
# !pip install ipython-sql psycopg2-binary
# Out:
# Requirement already satisfied: ipython-sql in c:\users\gebruiker\anaconda3\lib\site-packages (0.5.0)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: prettytable in c:\users\gebruiker\appdata\roaming\python\python312\site-packages (from ipython-sql) (3.5.0)
# Requirement already satisfied: ipython in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (8.27.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (2.0.43)
# Requirement already satisfied: sqlparse in c:\users\gebruiker\appdata\roaming\python\python312\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\gebruiker\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: decorator in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\gebruiker\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\gebruiker\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\gebruiker\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\gebruiker\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\gebruiker\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\gebruiker\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Downloading psycopg2_binary-2.9.12-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------------------- ------------- 1.8/2.8 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 9.4 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.12
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Users\Gebruiker\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\Gebruiker\AppData\Roaming\Python\Python312\site-packages)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:rotterdam22A@@localhost:5432/postgres
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 144, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3319, in raw_connection
#     return self.pool.connect()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 448, in connect
#     return _ConnectionFairy._checkout(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1272, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 712, in checkout
#     rec = pool._do_get()
#           ^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 178, in _do_get
#     with util.safe_reraise():
#          ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 122, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 176, in _do_get
#     return self._create_connection()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 389, in _create_connection
#     return _ConnectionRecord(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 674, in __init__
#     self.__connect()
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 900, in __connect
#     with util.safe_reraise():
#          ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 122, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 896, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 667, in connect
#     return dialect.connect(*cargs_tup, **cparams)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 630, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\psycopg2\__init__.py", line 135, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.OperationalError: connection to server on socket "@localhost/.s.PGSQL.5432" failed: Invalid argument (0x00002726/10022)
# 	Is the server running locally and accepting connections on that socket?
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sql\connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#                                ^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3295, in connect
#     return self._connection_cls(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2450, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 144, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3319, in raw_connection
#     return self.pool.connect()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 448, in connect
#     return _ConnectionFairy._checkout(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1272, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 712, in checkout
#     rec = pool._do_get()
#           ^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 178, in _do_get
#     with util.safe_reraise():
#          ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 122, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 176, in _do_get
#     return self._create_connection()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 389, in _create_connection
#     return _ConnectionRecord(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 674, in __init__
#     self.__connect()
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 900, in __connect
#     with util.safe_reraise():
#          ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 122, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 896, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 667, in connect
#     return dialect.connect(*cargs_tup, **cparams)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 630, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Gebruiker\anaconda3\Lib\site-packages\psycopg2\__init__.py", line 135, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) connection to server on socket "@localhost/.s.PGSQL.5432" failed: Invalid argument (0x00002726/10022)
# 	Is the server running locally and accepting connections on that socket?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
from getpass import getpass
password = getpass("PostgreSQL password: ")
# Out:
# PostgreSQL password:  ········

# %%
import psycopg2

conn = psycopg2.connect(
    host="127.0.0.1",
    port=5432,
    database="postgres",
    user="postgres",
    password=password
)

conn
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="127.0.0.1",
#       5     port=5432,
#       6     database="postgres",
#       7     user="postgres",
#       8     password=password
#       9 )
#      11 conn
#
# File ~\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password=password,
    host="localhost",
    port="5432"
)

print("Connected!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[13], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     dbname="postgres",
#       5     user="postgres",
#       6     password=password,
#       7     host="localhost",
#       8     port="5432"
#       9 )
#      11 print("Connected!")
#
# File ~\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="dvdrental",
    user="postgres",
    password="alireza22A"
)

print("Connected!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[19], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="localhost",
#       5     port=5432,
#       6     database="dvdrental",
#       7     user="postgres",
#       8     password="alireza22A"
#       9 )
#      11 print("Connected!")
#
# File ~\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="postgres",
    user="postgres",
    password="postgres123"
)

print("Connected!")
# Out:
# Connected!
