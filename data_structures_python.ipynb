# %% [markdown]
# ## Real-World Examples Using Lists in Python

# %% [markdown]
# ### Create a To Do List To Keep Track OF Tasks

# %%
to_do_list = ["buy groceris", "make an exercise", "do homework", "clean the room", "pay bills"]

## adding the task

to_do_list.append("schedule meetings")
to_do_list.append("go for a run")

# %%
to_do_list
# Out:
# ['buy groceris',
#  'make an exercise',
#  'do homework',
#  'clean the room',
#  'pay bills',
#  'schedule meetings',
#  'go for a run']

# %%
# removing a completed task

to_do_list.remove("clean the room")

to_do_list
# Out:
# ['buy groceris',
#  'make an exercise',
#  'do homework',
#  'pay bills',
#  'schedule meetings',
#  'go for a run']

# %%
## checking if a task is in the list

if "pay bills" in to_do_list:
    print("don't forget to pay the utility bills")
# Out:
# don't forget to pay the utility bills

# %%
print("to do list remaing")

for task in to_do_list:
    print(f"-{task}")
# Out:
# to do list remaing
# -buy groceris
# -make an exercise
# -do homework
# -pay bills
# -schedule meetings
# -go for a run

# %%
## Create a list to store and calculate average grades for students
grades = [87, 69, 59, 81]

# adding a new grade 
grades.append(95)

average_grade = sum(grades)/len(grades)
print(f"Average grade: {average_grade:.2f}")
# Out:
# Average grade: 78.20

# %%
## find the highest and lowest grade

highest_grade = max(grades)
lowest_grade = min(grades)

print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Highest Grade: 95
# Lowest Grade: 59

# %% [markdown]
# ## managing an inventory

# %%
## Use a list to manage inventory items in a store

# %%
## managing an inventory

inventory = ["apples", "bananas", "oranges", "grapes"]

# adding a new item 
inventory.append("strawberries")

## removing an item that is out of stock
inventory.remove("bananas")

# %%
## checking an item is in stock

item = "strawberries"

if item in inventory:
    print(f"{item} are in stock")
else:
    print(f"{item} is out of stock")
# Out:
# strawberries are in stock

# %%
## printing the inventory list

print("Inventory list: ")

for item in inventory:
    print(f"-{item}")
# Out:
# Inventory list:
# -apples
# -oranges
# -grapes
# -strawberries

# %% [markdown]
# ## collectin user facebook

# %%
## use a list to collect and analyze user facebook

# %%
feedback = ["great service!", "very satisfied", "Could be better", "Excellent experience"]

## adding new feedback
feedback.append("not happy with the service")


print(feedback)
# Out:
# ['great service!', 'very satisfied', 'Could be better', 'Excellent experience', 'not happy with the service']

# %%
## counting specific feedback

positive_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())

print(f"positive feedback count: {positive_feedback_count}")
# Out:
# positive feedback count: 2

# %%
## printing all feedback

print("user feedback: ")
for comment in feedback:
    print(f"-{comment}")
# Out:
# user feedback:
# -great service!
# -very satisfied
# -Could be better
# -Excellent experience
# -not happy with the service

# %% [markdown]
# # Sets

# %%
### create a set

my_set = {1,2,3,4,5}

print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(type(my_set))
# Out:
# <class 'set'>

# %%
my_empty_set = set()
print(type(my_empty_set))
# Out:
# <class 'set'>

# %%
my_set = set([1,2,3,4,5])
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set = set([1,2,3,4,6,4,5])
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
## basics  sets opertaions
## adding and removing elements in set

my_set.add(7)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.add(5)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
## remove an element from the set
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
my_set.remove(10)
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 my_set.remove(10)
#       2 print(my_set)
#
# KeyError: 10

# %%
## discared method ==> remove an element from a set if it is a number

my_set.discard(10)
print(my_set)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
## removing a random element ===> pop method
removed_element = my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 2
# {3, 5, 6, 7}

# %%
## clear all the elements

my_set.clear()
print(my_set)
# Out:
# set()

# %%
## set membership test
my_set = {1,2,3,4,5}

print(3 in my_set)
# Out:
# True

# %%
print(10 in my_set)
# Out:
# False

# %%
## mathematical operations

set1 = {1,2,3,4,6}
set2 = {4,5,6,7,8,9}

## Union  == > union method combines everything

union_set = set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
## intersectional

## mathematical operations

set1 = {1,2,3,4,6}
set2 = {4,5,6,7,8,9}

## Union  == > union method combines everything

intersection_set = set1.intersection(set2)
print(intersection_set)

print(set1)
# Out:
# {4, 6}
# {1, 2, 3, 4, 6}

# %%
set1.intersection_update(set2)
print(set1)
# Out:
# {4, 6}

# %%
## difference
set1 = {1,2,3,4,6}
set2 = {4,5,6,7,8,9}
set1.difference(set2)
# Out:
# {1, 2, 3}

# %%
set1.difference_update(set2)
print(set1)
# Out:
# {1, 2, 3}

# %%
## difference
set1 = {1,2,3,4,6}
set2 = {4,5,6,7,8,9}
set2.difference(set1)
# Out:
# {5, 7, 8, 9}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 3, 5, 7, 8, 9}

# %% [markdown]
# ### sets method

# %%
set1 = {1,2,3,4,5}
set2= {3,4,5}

## is subset

print(set1.issubset(set2))
# Out:
# False

# %%
print(set1.issuperset(set2))
# Out:
# True

# %%
set1 = {1,2,3}
set2= {3,4,5}

## is subset

print(set1.issubset(set2))
# Out:
# False

# %%
lst = [1,2,2,3,4,4,5]

## remove the duplicate from this list

set(lst)
# Out:
# {1, 2, 3, 4, 5}

# %%
### Counting Unique words in text

text="In this tutorial we are discussing about sets that we are discussing"

words = text.split()

## convert list of words to set to get unique words



unique_words = set(words)

print(len(unique_words))

unique_words
# Out:
# 9
# {'In', 'about', 'are', 'discussing', 'sets', 'that', 'this', 'tutorial', 'we'}

# %% [markdown]
# # Tuples

# %%
## introduction
## tuples are ordered collection of items that are immutable. (unchangable)  they are similar to lists, but their immutablity makes them different

## creating  a tuble

empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1,2,3,4,5,6])  ## give a list to tuple()

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4))
# Out:
# [1, 2, 3, 4]

# %%
mixed_tuple = (1, "hello", True, 3.4)

print(mixed_tuple)
# Out:
# (1, 'hello', True, 3.4)

# %%
## accessing tuple elements
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[1])
print(numbers[-1])
# Out:
# 2
# 6

# %%
numbers[0:3]
# Out:
# (1, 2, 3)

# %%
numbers[:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::]
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %% [markdown]
# ### tuple opretaions

# %%
 mixed_tuple
# Out:
# (1, 'hello', True, 3.4)

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
concatination_tuple = numbers + mixed_tuple
print(concatination_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'hello', True, 3.4)

# %%
mixed_tuple * 3
# Out:
# (1, 'hello', True, 3.4, 1, 'hello', True, 3.4, 1, 'hello', True, 3.4)

# %%
numbers * 3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## immutable nature of tuples

## tuples are immutable, which maens that elements can not be changed once assigned

lst = [1,2,3,4,5]
print(lst)

lst[1] = "krish"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'krish', 3, 4, 5]

# %%
numbers[1] = "krish"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 numbers[1] = "krish"
#
# TypeError: 'tuple' object does not support item assignment

# %%
## tuple methods

print(numbers)
print(numbers.count(1))
# Out:
# (1, 2, 3, 4, 5, 6)
# 1

# %%
print(numbers.index(3))
# Out:
# 2

# %% [markdown]
# ### pakking and unpakking a tuple

# %%
## packing

packed_tuple = 1, "Hello", 3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
## unpacking atuple

a,b,c = packed_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
## unpacking with *

numbers = (1,2,3,4,5,6)

first, *middle, last = numbers

print(first)

print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## unpacking with *

numbers = (1,2,3,4,5,6,8,9,24)

first, *middle, last = numbers

print(first)

print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5, 6, 8, 9]
# 24

# %% [markdown]
# #### Nested tuple

# %%
## nested list

lst = [[1,2,3,4],[5,6,7], [1,"hello", 3.14, "c"]]

lst[0]
# Out:
# [1, 2, 3, 4]

# %%
lst[0][2]
# Out:
# 3

# %%
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
## nested tuples

## this is just list but there is a tuple in list
lst = [[1,2,3,4],[5,6,7], (1,"hello", 3.14, "c")]

lst[2]
# Out:
# (1, 'hello', 3.14, 'c')

# %%
## nested tuple 
## this is a nested tuple

nested_tuple = ((1,2,3,4), ("a", "b", "c"), (True, False))

## access the element inside a tuple

print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3, 4)
# c

# %%
## iterating over nested tuples

nested_tuple = ((1,2,3,4), ("a", "b", "c"), (True, False))

for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item, end = " ")
    print()
# Out:
# 1
# 2
# 3
# 4
#
# a
# b
# c
#
# True
# False
