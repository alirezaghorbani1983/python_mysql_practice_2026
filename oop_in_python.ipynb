# %% [markdown]
# ## OOP in python

# %% [markdown]
# ### Classes and Objects

# %% [markdown]
# ####  Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs.
# #### OOP allows for modeling real-world scenarios using classes and objects.

# %% [markdown]
# #### A class is a blue print for creating objects. it has several attributes and methods

# %%
class Car:   ## class is a real world identity object (blueprint) is instantialized from class
    pass

audi = Car()
bmw = Car()
print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
audi.windows = 4  ## initializing of attribute is not a proper way
print(audi.windows)
# Out:
# 4

# %%
tata = Car()
tata.doors = 4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 tata = Car()
#       2 tata.doors = 4
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
### instance variable and methodes 
### instance variable
class Dog:
    ## constructor
    ## define instance variable (define attributes)
    def __init__(self,name, age):
        self.name = name
        self.age = age

## create an object
dog1 = Dog('buddy',3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# buddy
# 3

# %%
dog2 = Dog('tito', 4)
print(dog2.name)
print(dog2.age)
# Out:
# tito
# 4

# %%
## define a class with instance methods
class Dog:
    def __init__(self,name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("buddy",3)
dog1.bark()
dog2 = Dog("suzy", 6)
dog2.bark()
# Out:
# buddy says woof
# suzy says woof

# %%
### modeling a bank account

## define a class for bank account
class BankAccount:
    ## constructor
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("insufficent funds!")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")

    def get_balance(self):
        return self.balance

# %%
## call instance method
account = BankAccount("Ali", 1000)
print(account.balance)
# Out:
# 1000

# %%
## call instance method
account.deposit(200)
# Out:
# 200 is deposited. New balance is 1200

# %%
## withdraw some money
account.withdraw(500)
# Out:
# 500 is withdrawn. New Balance is 700

# %%
print(account.get_balance())
# Out:
# 700

# %% [markdown]
# ## Inheritance In Python

# %% [markdown]
# #### Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows a class to inherit attributes and methods from another class.
#
# #### This lesson covers single inheritance and multiple inheritance, demonstrating how to create and use them in Python

# %%
## Inheritance (Single Inheritance)
## defining Parent class

class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

# %%
car1 = Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the petrol car

# %%
## single inheritance
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):
        super().__init__(windows, doors, enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving : {self.is_selfdriving}")

# %%
tesla1 = Tesla(4,5,"electric", True)
print(tesla1.selfdriving())
# Out:
# Tesla supports self driving : True
# None

# %%
tsela1.drive()
# Out:
# The person will drive the electric car

# %%
### multiple inheritance
## when a class inherits from more thane one base class
## base class 1

class Animal:
    def __init__(self,name):
        self.name = name

    def speak(self):
        print("Subclass must implement this method")

## base class 2
class Pet:
    def __init__(self, owner):
        self.owner = owner

## derived class
class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self,name)
        Pet.__init__(self, owner)

    def speak(self):
        return f"{self.name} say woof"
        
## Create an object 
dog = Dog("Buddy", "Ali")
print(dog.speak())
print(f"Owner: {dog.owner}")
# Out:
# Buddy say woof
# Owner: Ali

# %% [markdown]
# ## Polymorphism

# %% [markdown]
# #### polymorphism  means multiple forms
# #### Polymorphism is a core concept in Object-Oriented Programming (OOP)
# #### that allows objects of different classes to be treated as objects of a common superclass.
#
# #### It provides a way to perform a single action in different forms.
# #### Polymorphism is typically achieved through method overriding and interfaces

# %% [markdown]
# ### method overriding
# #### Method overriding allows a child class to provide a specific implementation of a method that is already defined in its parent class.

# %% [markdown]
# #### The purpose of inheritance is that:
#
# The parent class defines general behavior.
# The child class defines more specific behavior.
#
# For this reason, Python—and almost all object-oriented programming languages (such as Java, C#, and C++)—first look for a method in the child class. If the method is not found there, they then search for it in the parent class.

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")


class Dog(Animal):
    def speak(self):
        print("Woof!")


dog = Dog()
dog.speak()
# Out:
# Woof!

# %%
class Dog(Animal):
    pass

dog = Dog()
dog.speak()
# Out:
# Animal makes a sound

# %%
class Animal:
    def speak(self):
        print("Some sound")


class Dog(Animal):
    def speak(self):
        print("Woof")


class Cat(Animal):
    def speak(self):
        print("Meow")

cat = Cat()
cat.speak()
# Out:
# Meow

# %%
## Base Class

class Animal:
    def speak(self):
        return "Sound of the animal"

## derived class 1
class Dog(Animal):
    def speak(self):
        return "Woof!"

## derived class 2
class Cat(Animal):
    def speak(self):
        return("Meouw!")

## function that demosnstrates polymorphism
def animal_speak(animal):
    print(animal.speak())


dog = Dog()
cat = Cat()

print(dog.speak())
print(cat.speak())

animal_speak(dog)
# Out:
# Woof!
# Meouw!
# Woof!

# %% [markdown]
# #### Polymorphism with functions and methodes

# %%
## base class
class Shape:
    def area(self):
        return "the area of the figure"

## derived class 1
class Rectangle(Shape):
    def __init__(self, heigth, width):
        self.width = width
        self.heigth = heigth

    def area(self):
        return self.width * self.heigth

## derived class 2

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return self.radius * self.radius * 3.14

## Fuction that demonstrates polymorphism

def print_area(shape):
    print(f"the area is {shape.area()}")


rectangle = Rectangle(4,5)
circle = Circle(3)
        
print_area(rectangle)   
print_area(circle)
# Out:
# the area is 20
# the area is 28.26

# %% [markdown]
# ### Polymorphism with Abstract Base Classes

# %% [markdown]
# #### Abstract Base Classes (ABCs) are used to define common methods for a group of related objects.
# #### They can enforce that derived classes implement particular methods, promoting consistency across different implementations.

# %%
from abc import ABC, abstractmethod

## Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass
        
## derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"

class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"       

# Function that demonstrates polymorphism
def start_vehicle(vehicle):
    print(vehicle.start_engine())
    
## create objects of car and motorcycle

car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# Car engine started
# Motorcycle engine started

# %% [markdown]
# ## Encapsulation And Abstraction

# %% [markdown]
# Encapsulation and abstraction are two fundamental principles of Object-Oriented Programming (OOP) that help in designing robust, maintainable, and reusable code. Encapsulation involves bundling data and methods that operate on the data within a single unit, while abstraction involves hiding complex implementation details and exposing only the necessary features.

# %% [markdown]
# ## Encapsulation
# #### Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit.
# #### It restricts direct access to some of the object's components, which is a means of preventing accidental interference and misuse of the data.

# %%
### Encapsulation with Getter and Setter methods

### three important access variables: Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name, age):
        self.name = name  ## public variables
        self.age = age ## public variables
        
### we can use public variables from outside of the class

person = Person("Ali", 42)
print(person.name)
# Out:
# Ali

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
### Encapsulation with Getter and Setter methods

### three important access variables: Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name, age):
        self.name = name  ## public variables
        self.age = age ## public variables
        
def get_name(person):
    return person.name

person = Person("Ali", 42)
get_name(person)
# Out:
# 'Ali'

# %%
class Person:
    def __init__(self,name, age):
        self.__name = name  ## private variables
        self.__age = age ## private variables

# %%
person = Person("Ali", 42)
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person:
    def __init__(self,name, age, gender):
        self.__name = name  ## private variables
        self.__age = age ## private variables
        self.gender = gender

# %%
person = Person("Ali", 42, "Male")
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
## private variable

class Person:
    def __init__(self,name, age, gender):
        self.__name = name  ## private variables
        self.__age = age ## private variables
        self.gender = gender

def get_name(person):
    return person.__name

person = Person("Ali", 42, "Male")
get_name(person) 

### private variable can not be accessed from outside of the class
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 13
#      10     return person.__name
#      12 person = Person("Ali", 42, "Male")
# ---> 13 get_name(person)
#      15 ### private variable can not be accessed from outside of the class
#
# Cell In[110], line 10, in get_name(person)
#       9 def get_name(person):
# ---> 10     return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
## protected variable
## protected variable ==> we can not protected variable outside the class but we can access it from derived class
class Person:
    def __init__(self,name, age, education):
        self._name = name  ## protected variables
        self._age = age ## protected variables
        self.education = education

class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(self, name, age, gender)
        
employee = Employee()


### private variable can not be accessed from outside of the class
# Out:
# 'Ali'

# %%
class Person:
    def __init__(self,name,age,gender):
        self._name=name    ## protected variables
        self._age=age      ## protected variables
        self.gender=gender

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)


employee=Employee("Ali",42,"Male")
print(employee._name)
# Out:
# Ali

# %%
## Encapsulation With Getter And Setter
class Person:
    def __init__(self,name,age):
        self.__name=name  ## Private access modifier or variable
        self.__age=age ## Private variable


    ## getter method 
    ## getter method allows us to access the private variable inside the class
    def get_name(self):
        return self.__name

    ## setter method for name 
    ## setter method hepl us to change any values that we gave to the name ==> name is private variable
    def set_name(self, name):
        self.__name = name

    ## getter method 
    def get_age(self):
        return self.__age

    ## setter method for age
    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("age can not be negattive")

## call all function
## create an object

person = Person("Ali", 42)

## Access and modify    private variables

print(person.get_name())
print(person.get_age())

person.set_age(40)
print(person.get_age())

person.set_age(-5)


            

## with the help of getter getter , we retrieve the data
## with the help of setter , we can change the data
# Out:
# Ali
# 42
# 40
# age can not be negattive

# %% [markdown]
# ## Abstraction

# %% [markdown]
# #### Abstraction is the concept of hiding the complex implementation details and showing only the necessary features of an object.
# #### This helps in reducing programming complexity and effort.

# %%
## example for abstraction
from abc import ABC, abstractmethod

## Abstract base class
class Vehicle(ABC):
    def drive(self):
        print("The vehicle is used for driving")

    #abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("Car engine started")
    
def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()

car = Car()
operate_vehicle(car)
# Out:
# Car engine started
# The vehicle is used for driving

# %% [markdown]
# ## Magic Methods

# %% [markdown]
# #### Magic methods in Python, also known as dunder methods (double underscore methods), are special methods that start and end with double underscores.
# #### These methods enable you to define the behavior of objects for built-in operations, such as arithmetic operations, comparisons, and more.

# %% [markdown]
# ### Magic Methods
# #### Magic methods are predefined methods in Python that you can override to change the behavior of your objects.
# ####Some common magic methods include:

# %%
'''
__init__': Initializes a new instance of a class.
__str__: Returns a string representation of an object.
__repr__: Returns an official string representation of an object.
__len__: Returns the length of an object.
__getitem__: Gets an item from a container.
__setitem__: Sets an item in a container.
'''
# Out:
# "\n__init__': Initializes a new instance of a class.\n__str__: Returns a string representation of an object.\n__repr__: Returns an official string representation of an object.\n__len__: Returns the length of an object.\n__getitem__: Gets an item from a container.\n__setitem__: Sets an item in a container.\n"

# %%
class Person:
    pass

person = Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)

# %%
## basic magic methods
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person("Ali", 42)
print(person)

# %%
## basic magic methods
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name}, {self.age} years old"

    def __repr__(self):
        return f"Person(name={self.name},age={self.age})"

person = Person("Ali", 42)
print(person)
print(repr(person))
# Out:
# Ali, 42 years old
# Person(name=Ali,age=42)

# %% [markdown]
# ## Custom exception (Raise and Throw an exception)

# %%
class Error(Exception):
    pass

## dob stands for date of birth
class dobException(Error):
    pass

# %%
### create the variable "year"

year = int(input("Enter the dob"))
age = 2026 - year

try:
    if age <= 30 and age >= 30:
        print("the age is valid so you can apply for the exam")
    else:
        raise dobException
except dobException:
    print("Your age is not appropriate for exam")
# Out:
# Enter the dob 1985
# Your age is not appropriate for exam

# %% [markdown]
# ## Classes and Objects Assignments

# %% [markdown]
# #### Create a class named Car with attributes make, model, and year. Create an object of the class and print its attributes.

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

## test 
car = Car("Audi", "A3", 1999)
print(car.make, car.model, car.year)
# Out:
# Audi A3 1999

# %% [markdown]
# #### Add a method named start_engine to the Car class that prints a message when the engine starts. Create an object of the class and call the method.

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def start_engine(self):
        print("the engine has started")

## test 
car = Car("Audi", "A3", 1999)
car.start_engine()
# Out:
# the engine has started

# %% [markdown]
# #### Create a class named Student with attributes name and age. Use a constructor to initialize these attributes. Create an object of the class and print its attributes.

# %%
class Student:
    def __init__(self, name, age):
        self.name = name 
        self.age = age

## tset
student_1 = Student("John", 23)
print(student_1.name, student_1.age)
# Out:
# John 23

# %% [markdown]
# #### Create a class named BankAccount with private attributes account_number and balance. Add methods to deposit and withdraw money, and to check the balance. Create an object of the class and perform some operations.

# %%
class BankAccount:
    def __init__(self, account_number, balance=0):
        self.__account_number = account_number
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount > self.__balance:
            print("Insufficient balance!")
        else:
            self.__balance -= amount

    def check_balance(self):
        return self.__balance

# Test
account = BankAccount('12345678', 1000)
account.deposit(500)
account.withdraw(200)
print(account.check_balance())  # 1300
account.withdraw(1800)  # will return Insufficient balance!
# Out:
# 1300
# Insufficient balance!

# %% [markdown]
# #### Create a base class named Person with attributes name and age. Create a derived class named Employee that inherits from Person and adds an attribute employee_id. Create an object of the derived class and print its attributes.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

# Test
employee = Employee('Alice', 30, 'E123')
print(employee.name, employee.age, employee.employee_id)
# Out:
# Alice 30 E123
