# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 32
# Height: 6.1
# Name: Krish

# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)

# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 32
# Height: 6.1
# Name: Krish

# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 32
# Height: 6.1
# Name: Krish

# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 32
# Height: 6.1
# Name: Krish

# %%
## Declaring And Assigning Variables

age=32
height=6.1
name="Krish"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 32
# Height: 6.1
# Name: Krish

# %% [raw]
# ## Understnading Variable types
# ## Python is dynamically typed,type of a variable is determined at runtime
# age=25 #int
# height=6.1 #float
# name="KRish" #str
# is_student=True #bool
#
# print(type(name))

# %%
## Understnading Variable types
## Python is dynamically typed,type of a variable is determined at runtime
age=25 #int
height=6.1 #float
name="KRish" #str
is_student=True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Gebruiker\\python_basics'

# %%
print(age)
# Out:
# 25

# %%
## naming convention
## vriable names should be descriptive
## They must start with a letter or an '_' and contains letter,numbers and underscores
## variables names case sensitive

# valid vriable names

first_name = "Krish"
last_name = "Naik"

# %%
# invalid variable names
## 2age
frist-name = "ak"
# Out:
#   Cell In[7], line 3
#     frist-name = "ak"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# vriable types
age = 25 # int
height = 6.1  # float
name = "ali" # string or str
is_student = True  # boolian

print(type(age))
# Out:
# <class 'int'>

# %%
## TYPE CHECKING AND conversion

type(height)
# Out:
# float

# %%
# type conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# 25
# <class 'str'>

# %%
age = '25'
int(age)
print(type(int(age)))
# Out:
# <class 'int'>

# %%
height = 6.33
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 6.0

# %%
## dynamic typing
## python aloows the type of a vriable to change as the program executes

var = 10 #int
print(var, type(var))

var = "hello"
print(var, type(var))

var = 3.11
print(var, type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.11 <class 'float'>

# %%
# input
age = input("what is the age")
print(age, type(age))
# Out:
# what is the age 23
# 23 <class 'str'>

# %%
## simple calculator

num1 = float(input("enter first number:"))
num2 = float(input("enter second number:"))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# enter first number: 44
# enter second number: 23
# Sum: 67.0
# Difference: 21.0
# Product: 1012.0
# Quotient: 1.9130434782608696
